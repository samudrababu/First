# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Samudra Sen**
# Assistant Professor

# %% [markdown]
# _I am interested in data science because I wish to be an analytics consultant.  Since I am a teacher, I want to offer courses on data science to my students.  Data science is one of the most rapidly emerging disciplines which holds promise for the future and is in high demand.  Therefore, I wish to take advantage of this trend and progress my career in this direction._

# %% [markdown]
# ### The code in the next cell prints the most widely used initial sentence in any programming language.

# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
#   ***
#   Horizontal rule
#   ***
#   ***
#   Another horizontal rule
#   ***
#
#   * This is a bulletted list.
#   + This is another point in a bulletted list.
#
#   1. This is point no. 1 in a numbered list
#   2. This is point no. 2 in a numbered list
#
# | Table | made | in | HTML Markdown |
# |---:|:---:|:---:|:---:|
# | Cell 1 | cell 2 | cell 3 | cell 4 |
# | cell 5 | cell 6 | cell 7 | cell 8 |
#
# ```python
# sentence_highlighting = "Python code syntax highlighting"
# print sentence_highlighting
# ```
# `Another example of code highlighting`
#
# [Have fun with this hyperlink!!](https://elgoog.im/)
#
# > This is an example of a blocked quote.  This is used to emulate a reply text.
#
# ~~This is a sentence in strikethrough.~~
